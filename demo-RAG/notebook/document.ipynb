# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a test document.",
    metadata={
        "source": "test_source",
        "author": "test_author",
        "date_created": "2024-06-01",
    },

)
doc
# Out:
# Document(metadata={'source': 'test_source', 'author': 'test_author', 'date_created': '2024-06-01'}, page_content='This is a test document.')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader

# load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",  # Pattern to match files
    loader_cls=TextLoader,  # loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",  # Pattern to match files
    loader_cls=PyMuPDFLoader,  # loader class to use
    show_progress=False

)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': '3.0.35 (5.1.21)', 'creator': '(unspecified)', 'creationdate': '2026-05-27T14:23:22+00:00', 'source': '..\\data\\pdf\\RESUMEE_bharat.pdf', 'file_path': '..\\data\\pdf\\RESUMEE_bharat.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-08T05:01:12+02:00', 'trapped': '', 'modDate': "D:20260608050112+02'00'", 'creationDate': "D:20260527142322+00'00'", 'page': 0}, page_content='LinkedIn: linkedin.com/in/bharat-varma-6222tg | GitHub: github.com/bharatvarma6222-TG\nPROFILE\nAI/ML enthusiast with hands-on experience building LLM-powered applications, Retrieval-Augmented Generation (RAG)\npipelines, and AI agents. Strong foundation in Python, embeddings, vector databases, and agent workflows. Seeking an AI/ML\nInternship in Agentic AI to contribute to real-world intelligent systems.\nSKILLS\nLanguages & Frameworks: Python · FastAPI · LangChain · LangGraph\nAI / ML: LLMs · RAG · Embeddings · Semantic Search · Prompt Engineering · Hugging Face\nAPIs & Platforms: OpenAI · Anthropic · LangSmith\nVector Databases: FAISS · Chroma\nDatabases: PostgreSQL · SQLite\nDevOps & Tools: Docker · Linux · Git & GitHub · Jupyter Notebook\nPROJECTS\nBehaviorOS V4 – Autonomous Behavioral Intelligence & Cognitive HUD\n• Built a real-time Windows behavioral analysis system using Win32 ctypes hooks (GetLastInputInfo, OpenInputDesktop) for\nOS-level activity telemetry, detecting idle, screen lock, and sleep states with a 3-second noise filter.\n• Deployed a local semantic classification engine (sentence-transformers/all-MiniLM-L6-v2) to embed window titles and classify\nsessions into 10 behavioral categories (coding, debugging, research, deep work, entertainment, etc.) entirely offline.\n• Engineered a LangGraph-driven daily briefing engine computing 13 behavioral metrics including longest focus streak,\ncontext-switching rate, and distraction frequency from raw SQLite telemetry logs.\n• Built a PyQt6 glassmorphic HUD overlay with a LeetCode-style memory heatmap calendar, live focus dials, and cognitive state\nsparklines, backed by an async pub/sub event bus and FastAPI gateway.\nLocal SLM App with Ollama – Offline Model Benchmarking\n• Deployed three small language models entirely offline using Ollama, eliminating cloud API dependency and addressing privacy\nand data-residency constraints.\n• Benchmarked inference performance measuring tokens/sec, first-token latency, and memory footprint across all three models\non identical hardware.\n• Documented quality-vs-speed tradeoffs to guide model selection based on latency budgets and task complexity.\nOffline ChatGPT Clone – Fully Local AI Assistant\n• Built a fully offline AI chat app using FastAPI, Streamlit, and Ollama (Qwen2.5:3b) with no cloud dependency.\n• Implemented streaming responses and persistent multi-conversation history via SQLite and SQLAlchemy.\n• Integrated LangChain RAG pipeline supporting PDF upload and local vector retrieval for context-aware responses.\nEDUCATION\nBachelor of Technology (B.Tech) – Computer Science\nParul University | Expected Graduation: 2027\nLEARNING & EXPERIENCE\n• Hands-on experience building LLM-powered applications using Hugging Face and LangChain.\n• Implemented RAG pipelines with FAISS and Chroma embedding-based retrieval.\n• Built AI agents with tool-calling and reasoning workflows through project-based learning.\n• Strong understanding of semantic search, cost optimization, and real-time data access.\n• Familiar with containerization using Docker and Unix/Linux environments for development and deployment.\nS Bharat Kumar Varma\nHyderabad, Telangana | bharatvarma6222@gmail.com | +91 9010079998')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
